# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **Pivot Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    537     66   John  January      Q1
# 1  2023-01-02       B   West    886     64   Mary  January      Q1
# 2  2023-01-03       C  North    562     23    Bob  January      Q1
# 3  2023-01-04       D  South    321     53  Alice  January      Q1
# 4  2023-01-05       A   East    915     40   John  January      Q1
# 5  2023-01-06       B   West    572     76   Mary  January      Q1
# 6  2023-01-07       C  North    331     93    Bob  January      Q1
# 7  2023-01-08       D  South    577     12  Alice  January      Q1
# 8  2023-01-09       A   East    265     24   John  January      Q1
# 9  2023-01-10       B   West    168     53   Mary  January      Q1
# 10 2023-01-11       C  North    813     97    Bob  January      Q1
# 11 2023-01-12       D  South    849     20  Alice  January      Q1
# 12 2023-01-13       A   East    767     61   John  January      Q1
# 13 2023-01-14       B   West    321     17   Mary  January      Q1
# 14 2023-01-15       C  North    969     58    Bob  January      Q1
# 15 2023-01-16       D  South    348     21  Alice  January      Q1
# 16 2023-01-17       A   East    385     16   John  January      Q1
# 17 2023-01-18       B   West    316     87   Mary  January      Q1
# 18 2023-01-19       C  North    822     73    Bob  January      Q1
# 19 2023-01-20       D  South    356     23  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales", index="Region", columns="Product", aggfunc= "median")
# Out:
# Product      A      B      C      D
# Region
# East     537.0    NaN    NaN    NaN
# North      NaN    NaN  813.0    NaN
# South      NaN    NaN    NaN  356.0
# West       NaN  321.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales','Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     573.8    NaN    NaN    NaN  41.4   NaN   NaN   NaN
# North      NaN    NaN  699.4    NaN   NaN   NaN  68.8   NaN
# South      NaN    NaN    NaN  490.2   NaN   NaN   NaN  25.8
# West       NaN  452.6    NaN    NaN   NaN  59.4   NaN   NaN

# %% [markdown]
# ### Cross Tabs

# %%
pd.crosstab(df['Region'], df['Product']) ## Used for countings
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
